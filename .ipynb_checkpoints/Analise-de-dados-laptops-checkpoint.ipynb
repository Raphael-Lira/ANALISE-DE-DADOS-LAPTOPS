# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df = pd.read_csv('laptops.csv', sep=',')
display(df)
# Out:
#      Unnamed: 0                                           img_link  \
# 0             0  https://rukminim1.flixcart.com/image/312/312/x...
# 1             1  https://rukminim1.flixcart.com/image/312/312/x...
# 2             2  https://rukminim1.flixcart.com/image/312/312/l...
# 3             3  https://rukminim1.flixcart.com/image/312/312/x...
# 4             4  https://rukminim1.flixcart.com/image/312/312/x...
# ..          ...                                                ...
# 979         979  https://rukminim1.flixcart.com/image/312/312/k...
# 980         980  https://rukminim1.flixcart.com/image/312/312/k...
# 981         981  https://rukminim1.flixcart.com/image/312/312/x...
# 982         982  https://rukminim1.flixcart.com/image/312/312/k...
# 983         983  https://rukminim1.flixcart.com/image/312/312/x...
#
#                                          name  price(in Rs.)  \
# 0               Lenovo Intel Core i5 11th Gen          62990
# ...

# %%
df_laptops_clear = df[['name', 'price(in Rs.)', 'processor', 'ram', 'os', 'storage', 'display(in inch)', 'rating', 'no_of_ratings', 'no_of_reviews']]
display(df_laptops_clear)
# Out:
#                                          name  price(in Rs.)  \
# 0               Lenovo Intel Core i5 11th Gen          62990
# 1              Lenovo V15 G2 Core i3 11th Gen          37500
# 2        ASUS TUF Gaming F15 Core i5 10th Gen          49990
# 3    ASUS VivoBook 15 (2022) Core i3 10th Gen          33990
# 4                     Lenovo Athlon Dual Core          18990
# ..                                        ...            ...
# 979         ASUS VivoBook 15 Core i3 10th Gen          37990
# 980       HP Chromebook MediaTek Kompanio 500          22670
# 981                    ASUS Ryzen 5 Hexa Core          54990
# 982            DELL Inspiron Core i3 11th Gen          40990
# 983           ASUS Celeron Dual Core 10th Gen          24540
#
#                                         processor               ram  \
# 0              Intel Core i5 Processor (11th Gen)    16 GB DDR4 RAM
# 1              Intel Core i3 Processor (11th Gen)     8 GB DDR4 RAM
# ...

# %%
df_laptops_clear = df_laptops_clear.fillna(0)
df_laptops_clear.isna().sum()
# Out:
# name                0
# price(in Rs.)       0
# processor           0
# ram                 0
# os                  0
# storage             0
# display(in inch)    0
# rating              0
# no_of_ratings       0
# no_of_reviews       0
# dtype: int64

# %%
desc_preco = df_laptops_clear['price(in Rs.)'].describe()
print(desc_preco)
# Out:
# count       984.000000
# mean      80960.720528
# std       57421.220919
# min       15990.000000
# 25%       42655.000000
# 50%       62990.000000
# 75%       94990.000000
# max      419990.000000
# Name: price(in Rs.), dtype: float64

# %%
plt.figure(figsize=(12,6))
sns.histplot(data = df_laptops_clear, x = 'price(in Rs.)', kde = True,bins=50)
plt.title('Range de preco')
plt.show()

# %%
lista_marcas = []
for laptop in df_laptops_clear['name']:
    lista_marcas.append(laptop.split()[0])
df_laptops_clear['Marca'] = lista_marcas

# %%
marcas_principais = df_laptops_clear['Marca'].value_counts().head(6)
plt.figure(figsize=(12,6))
plt.bar(marcas_principais.index, marcas_principais.values, color=["#9219BC", "#208E31", "#2E43B0", "#E3D242", "#E3702F", '#E32F2F'])
plt.show()

# %%
for processador, quantidade in df_laptops_clear['processor'].value_counts().items():
    if quantidade < 70:
        df_laptops_clear.loc[df_laptops_clear['processor'] == processador, 'processor']= 'Random'
df_laptops_clear['processor'].value_counts()
# Out:
# Random                                447
# Intel Core i3 Processor (11th Gen)    131
# Intel Core i5 Processor (11th Gen)    129
# Intel Core i5 Processor (12th Gen)    101
# AMD Ryzen 5 Hexa Core Processor        93
# AMD Ryzen 7 Octa Core Processor        83
# Name: processor, dtype: int64

# %%
plt.figure(figsize=(18,6))
df_laptops_clear.groupby('processor').size().sort_values(ascending = False).head(5).plot(kind = 'bar', color = sns.color_palette("coolwarm"))
plt.xlabel("Processor")
plt.ylabel("Frequency")
plt.title("Top 6 Processadores")
plt.xticks(rotation=0)
plt.show()

# %%
for ram, quantidade in df_laptops_clear['ram'].value_counts().items():
    if quantidade < 23:
        df_laptops_clear.loc[df_laptops_clear['ram'] == ram, 'ram']= 'Random'
df_laptops_clear['ram'].value_counts()
# Out:
# 8 GB DDR4 RAM       463
# 16 GB DDR4 RAM      235
# Random              146
# 16 GB DDR5 RAM       72
# 4 GB DDR4 RAM        45
# 8 GB LPDDR4X RAM     23
# Name: ram, dtype: int64

# %%
plt.figure(figsize=(12,6))
df_laptops_clear.groupby('ram').size().sort_values(ascending = False).head(6).plot(kind = 'bar', color = sns.color_palette("coolwarm"))
plt.xlabel("Variedades de ram")
plt.ylabel("Frequency")
plt.xticks(rotation=0)
plt.title("Top 6 RAMS")
plt.show()

# %%
plt.figure(figsize=(15,6))
df_laptops_clear.groupby('display(in inch)').size().sort_values(ascending = False).head(6).plot(kind = 'bar', color = sns.color_palette("coolwarm"))
plt.xlabel("Tamanho de monitor")
plt.ylabel("Frequency")
plt.xticks(rotation=0)
plt.title("Top 6 tamanhos de monitores")
plt.show()
